# %%
import json

with open('../dataset_text_rec/train_task2_labels.json') as f:
    data = json.load(f)

labels = []
for i in sorted(data, key = lambda x: (int(x.split("_")[1]), int(x.split("_")[2]))):
    if data[i][0]['language'] == 'Latin':
        labels.append(data[i][0]['transcription'])

# %%
import json

with open('../dataset_text_rec/train_task2_labels.json') as f:
    data = json.load(f)

# %%
import numpy as np

np.save('../dataset_text_rec/labels', labels)

# %%
import numpy as np

# %%
import imageio
import glob

imgs = []
for i in sorted(data, key = lambda x: (int(x.split("_")[1]), int(x.split("_")[2]))):
    if data[i][0]['language'] == 'Latin':
        imgs.append(imageio.imread("../dataset_text_rec/train_task2_images/" + i + ".jpg"))
imgs = np.array(imgs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cf3c4c7a8a05> in <module>
#       6     if data[i][0]['language'] == 'Latin':
#       7         imgs.append(imageio.imread("../dataset_text_rec/train_task2_images/" + i + ".jpg"))
# ----> 8 imgs = np.array(imgs)
#
# NameError: name 'np' is not defined

# %%
imgs = np.array(imgs)
# Out:
# <ipython-input-4-05d4d7714def>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   imgs = np.array(imgs)

# %%
import cv2

def resize_dataset(imgs, dim):
    res_imgs = []
    for img in imgs:
        res_imgs.append(cv2.resize(img, dim))
    return np.array(res_imgs)

# %%
res_imgs = resize_dataset(imgs, (128, 128))

# %%
np.savez_compressed('../dataset_text_rec/imgs', res_imgs)

# %%
import tensorflow as tf

print(tf.strings.unicode_split(labels[0], input_encoding='UTF-8'))
# Out:
# tf.Tensor([b'E' b'S' b'T'], shape=(3,), dtype=string)

# %%
labels[0]
# Out:
# 'EST'

# %%
res_imgs.shape
# Out:
# (36220, 280, 280, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(res_imgs[0])
plt.show()

# %%
from trdg.generators import GeneratorFromWikipedia, GeneratorFromRandom  
import cv2
from skimage import color
import numpy as np

base_generator = GeneratorFromRandom(use_symbols=False, use_letters=True, length=1, width=128, size=32)
text = []
labels = []
for i in range(10000):
    print(i)
    img, lbl = next(base_generator)
    img = cv2.resize(np.array(img), (128, 128))
    img = color.rgb2gray(img)
    text.append(img)
    labels.append(lbl)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1c35040ee74b> in <module>
#       8 labels = []
#       9 for _ in range(10000):
# ---> 10     img, lbl = next(base_generator)
#      11     img = cv2.resize(np.array(img), (128, 128))
#      12     img = color.rgb2gray(img)
#
# ~/.local/lib/python3.8/site-packages/trdg/generators/from_random.py in __next__(self)
#      95
#      96     def __next__(self):
# ---> 97         return self.next()
#      98
#      99     def next(self):
#
# ~/.local/lib/python3.8/site-packages/trdg/generators/from_random.py in next(self)
#     108                 self.language,
#     109             )
# --> 110         return self.generator.next()
#
# ~/.local/lib/python3.8/site-packages/trdg/generators/from_strings.py in next(self)
#      82         self.generated_count += 1
#      83         return (
# ---> 84             FakeTextDataGenerator.generate(
#      85                 self.generated_count,
#      86                 self.strings[(self.generated_count - 1) % len(self.strings)],
#
# ~/.local/lib/python3.8/site-packages/trdg/data_generator.py in generate(cls, index, text, font, out_dir, size, extension, skewing_angle, random_skew, blur, random_blur, background_type, distorsion_type, distorsion_orientation, is_handwritten, name_format, width, alignment, text_color, orientation, space_width, character_spacing, margins, fit, output_mask, word_split, image_dir, stroke_width, stroke_fill, image_mode)
#     129                 * (float(size - vertical_margin) / float(distorted_img.size[1]))
#     130             )
# --> 131             resized_img = distorted_img.resize(
#     132                 (new_width, size - vertical_margin), Image.ANTIALIAS
#     133             )
#
# /usr/lib/python3/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1853         if self.mode in ["LA", "RGBA"]:
#    1854             im = self.convert(self.mode[:-1] + "a")
# -> 1855             im = im.resize(size, resample, box)
#    1856             return im.convert(self.mode)
#    1857
#
# /usr/lib/python3/dist-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1871                 )
#    1872
# -> 1873         return self._new(self.im.resize(size, resample, box))
#    1874
#    1875     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:
